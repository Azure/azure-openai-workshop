# %%
# Login to Azure
# !az login
# Out:
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f3f672c1-6cfc-4f72-92ae-2b1ab1c0cf69",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Microsoft Azure Internal Consumption",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "051e35b8-3c25-4f5a-af46-c84a35ad240d",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ES-PFE-FTE-LOUISLI",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "09e8ad18-7bdb-43b8-80c4-43ee53460e0b",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Partner Portfolio DEV",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "bac420ed-c6fc-4a05-8ac1-8c0c52da1d6e",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "IDEAs MS Reporting",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "dd4c2dac-db51-4cd0-b734-684c6cc360c1",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Geneva Analytics Intelligent Data Test (Corp)",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "9ec1d932-0f3f-486c-acc6-e7d78b358f9b",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "TScience",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8c2c7b23-848d-40fe-b817-690d79ad9dfd",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Purview_Demo_PartnerSandbox",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "29de2cfc-f00a-43bb-bdc8-3108795bd282",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "MSFT-Modern Device-Modern Mgmt-Imaging00",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7afc2d66-d5b4-4e84-970b-a782e3e4cc46",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "CLOUDBUILD-ANYBUILD-POC-01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7d411d23-59e5-4e2e-8566-4f59de4544f2",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Dev:ER: CE Security Service Operation Center",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "0368444d-756e-4ca6-9ecd-e964248c227a",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AnyBuild-InternalProdClusters",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "cb9eb375-570a-4e75-b83a-77dd942bee9f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "PPP_ACBB_ATS_AKS_NonProd",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "009d0e9f-a42a-470e-b315-82496a88cf0f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Weather and Finance Prod",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e686ef8c-d35d-4e9b-92f8-caaaa7948c0a",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Applied Sciences Group Dev",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "6f53185c-ea09-4fc3-9075-318dec805303",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "33e01921-4d64-4f8c-a055-5bdaffd5e33d"
#       }
#     ],
#     "name": "RPSAAS CSM Dogfood",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "dcbdac96-1896-478d-89fc-c95ed43f4596",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "pgattikoppul Projects",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "3b2fda06-3ef6-454a-9dd5-994a548243e9",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Microsoft Employee & Executive Communications",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "227531a4-d775-435b-a878-963ed8d0d18f",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "cdc5aeea-15c5-4db6-b079-fcadd2505dc2"
#       },
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Skype-1ES-DEV",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "432a7068-99ae-4975-ad38-d96b71172cdf",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Azure Profiler - Testing",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "1278a874-89fc-418c-b6b9-ac763b000415",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "(NBrady) Microsoft Azure Internal Consumption",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "2145a411-d149-4010-84d4-40fe8a55db44",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "ARM Test Environment",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "0cd6095b-b140-41ec-ad1d-32f2f7493386",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "1IS - One Integration Service - NonProduction",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4628298e-882d-4f12-abf4-a9f9654960bb",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ES_DeveloperProductivity_Dev",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "9fdc92bf-515a-49a9-bafd-f8a112bb9850",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "TimChap Microsoft Azure Internal Consumption",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "c0620f27-ac38-468c-a26b-264009fe7c41",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AzureQualityInfrastructureSubscription-Test00",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b68b2f37-1d37-4c2f-80f6-c23de402792e",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Semantic Machines R&D Subscription 1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "54b875cc-a81a-4914-8bfd-1a36bc7ddf4d",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "MSFT-WindowsVirtualDesktop-01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e4e06275-58d1-4081-8f1b-be12462eb701",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "CSR-CUSPOC-MST-Hiramfleitas",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "3cd95ff9-ac62-4b5c-8240-0cd046687ea0",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Internal App Insights Resources for Perflens",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "bbe41737-1ade-44df-8e33-217f11b8b452",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Service Profiler Development",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "1163fbbe-27e7-4b0f-8466-195fe5417043",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       },
#       {
#         "tenantId": "d0ecd01b-d782-448e-bae0-c3cad0e0543a"
#       },
#       {
#         "tenantId": "94c4857e-1130-4ab8-8eac-069b40c9db20"
#       },
#       {
#         "tenantId": "f702a9dc-ae48-4dc7-8f0a-8155a6dfa4e5"
#       }
#     ],
#     "name": "Python_AI_Tools_PM_Team_Sub",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8ae1955e-f748-4273-a507-10159ba940f9",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "SPO-CyrusB",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "9b4236fe-df75-4289-bf00-40628ed41fd9",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Customer Confidence Proof of Concepts",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a5f9f0d3-a937-4de5-8cf3-387fce51e80c",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "anguil",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "13723929-6644-4060-a50a-cc38ebc5e8b1",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "LinuxMdsd Test",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "10d0b7c6-9243-4713-91a9-2730375d3a1b",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ASutton Subscription",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "3905431d-c062-4c17-8fd9-c51f89f334c4",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Pytorch Build",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "9372b318-ed3a-4504-95a6-941201300f78",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "OE-Service Management Platform - External - Prod",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e0fd569c-e34a-4249-8c24-e8d723c7f054",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AML - Responsible AI R&D",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "56207a5d-4746-4a2d-9f7f-c5ac77a5ddfd",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Traffic manager Preview",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "bac044cf-49e1-4843-8dda-1ce9662606c8",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "UI Fabric",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ca38bc19-cf50-48e2-bbe6-8c35b40212d8",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Maps Mining Azure",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b2a328a7-ffff-4c09-b643-a4758cf170bc",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AISC-DEV-02",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "85b3dbca-5974-4067-9669-67a141095a76",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "027fe226-784c-4798-a157-5e0e7893424d"
#       }
#     ],
#     "name": "Terraform Testing on Azure with TTL = 2 Days",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8cff5d56-95fb-4a74-ab9d-079edb45313e",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "cdc5aeea-15c5-4db6-b079-fcadd2505dc2"
#       }
#     ],
#     "name": "Skype-NetEM-STAGING",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "68f3658f-0090-4277-a500-f02227aaee97",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "zejunz",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "79f57c16-00fe-48da-87d4-5192e86cd047",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "TScienceGPU",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ae71ef11-a03f-4b4f-a0e6-ef144727c711",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Bing MM Measurement",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "eec2de82-6ab2-4a84-ae5f-57e9a10bf661",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ServicesPortfolio MCS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e72e5254-f265-4e95-9bd2-9ee8e7329051",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Speech Services - DEV - SDK (rob)",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "eef8b6d5-94da-4b36-9327-a662f2674efb",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AISC-EngSys-01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ad203158-bc5d-4e72-b764-2607833a71dc",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna Build",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d2c9544f-4329-4642-b73d-020e7fef844f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "HPCScrub1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "5e552837-76cb-48b1-8983-b12ca284552b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "jawelch",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "caffe3c0-acbd-4d01-af76-a45f421bfb64",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Azure_Base_LivesiteArmory_test",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "df479416-a3f3-42b4-97ab-0a0a2b788ba3",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Windows Azure Internal Consumption",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "16b3c013-d300-468d-ac64-7eda0820b6d3",
#     "id": "8480def5-8f7a-4285-99f7-295b61d7b22a",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "MCAPS-Hybrid-REQ-42154-2022-louisli",
#     "state": "Enabled",
#     "tenantId": "16b3c013-d300-468d-ac64-7eda0820b6d3",
#     "user": {
#       "name": "louisli@microsoft.com",
#       "type": "user"
#     }
#   }
# ]
# WARNING: A web browser has been opened at https://login.microsoftonline.com/organizations/oauth2/v2.0/authorize. Please continue the login in the web browser. If no web browser is available or if the web browser fails to open, use device code flow with `az login --use-device-code`.
# WARNING: Failed to authenticate 10b290c5-28fe-4d84-a834-b81c51dd50bd 'PRESTO, A Division of Metrolinx' due to error 'AADSTS50158: External security challenge not satisfied. User will be redirected to another page or authentication provider to satisfy additional authentication challenges.
#
# Trace ID: 1399f41e-bf4c-46e9-a2bc-0f8028c00a00
#
# Correlation ID: 0a89c834-9e8b-4ee2-8e6e-c69ec2a2b3d4
#
# Timestamp: 2023-01-21 15:29:29Z'
# WARNING: Failed to authenticate 2008ffa9-c9b2-4d97-9ad9-4ace25386be7 'TC/TC' due to error 'AADSTS500571: The guest user account is disabled.
#
# Trace ID: 76d4f585-f0b3-4c31-a7c0-fb3bf1430c00
#
# Correlation ID: 04c0fc80-5547-4307-8832-2796f3eedf56
#
# Timestamp: 2023-01-21 15:29:30Z'
# WARNING: The following tenants don't contain accessible subscriptions. Use 'az login --allow-no-subscriptions' to have tenant level access.
# WARNING: 5fe7edeb-0b8e-4383-a697-ff6218746793 'Wellington Management'
# WARNING: e0ebf0fa-d1df-48f1-aaa6-ff24bd46ecc1 'Default Directory'
# WARNING: b638fefb-44c0-4879-b7a2-6ae56bca99c0 'RRLM'

# %%
# Use Non-prod subscription
# !az account set --subscription  MCAPS-Hybrid-REQ-42154-2022-louisli

# %%
openai_rg_name = 'OAIResourceGroup'
openai_svc_name = 'MyOpenAIResource'
# !az group create --name $openai_rg_name --location southcentralus
# Out:
# {
#   "id": "/subscriptions/8480def5-8f7a-4285-99f7-295b61d7b22a/resourceGroups/OAIResourceGroup",
#   "location": "southcentralus",
#   "managedBy": null,
#   "name": "OAIResourceGroup",
#   "properties": {
#     "provisioningState": "Succeeded"
#   },
#   "tags": null,
#   "type": "Microsoft.Resources/resourceGroups"
# }

# %% [markdown]
# # Create OpenAI service
# Update -l parameter value for a new endpoint uri

# %%
# Wait until the resource group is created
# Create OpenAI service
# !az cognitiveservices account create -n $openai_svc_name -g $openai_rg_name -l southcentralus --kind OpenAI --sku s0 --subscription 8480def5-8f7a-4285-99f7-295b61d7b22a
# Out:
# {
#   "etag": "\"ca0063d3-0000-0500-0000-63cc177d0000\"",
#   "id": "/subscriptions/8480def5-8f7a-4285-99f7-295b61d7b22a/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource",
#   "identity": null,
#   "kind": "OpenAI",
#   "location": "southcentralus",
#   "name": "MyOpenAIResource",
#   "properties": {
#     "allowedFqdnList": null,
#     "apiProperties": null,
#     "callRateLimit": {
#       "count": null,
#       "renewalPeriod": null,
#       "rules": [
#         {
#           "count": 30.0,
#           "dynamicThrottlingEnabled": null,
#           "key": "openai",
#           "matchPatterns": [
#             {
#               "method": "*",
#               "path": "openai/*"
#             }
#           ],
#           "minCount": null,
#           "renewalPeriod": 1.0
#         },
#         {
#           "count": 30.0,
#           "dynamicThrottlingEnabled": null,
#           "key": "default",
#           "matchPatterns": [
#             {
#               "method": "*",
#               "path": "*"
#             }
#           ],
#           "minCount": null,
#           "renewalPeriod": 1.0
#         }
#       ]
#     },
#     "capabilities": [
#       {
#         "name": "VirtualNetworks",
#         "value": null
#       },
#       {
#         "name": "MaxFineTuneCount",
#         "value": "100"
#       },
#       {
#         "name": "MaxRunningFineTuneCount",
#         "value": "1"
#       },
#       {
#         "name": "MaxUserFileCount",
#         "value": "50"
#       },
#       {
#         "name": "MaxTrainingFileSize",
#         "value": "100000000"
#       },
#       {
#         "name": "MaxUserFileImportDurationInHours",
#         "value": "1"
#       },
#       {
#         "name": "MaxFineTuneJobDurationInHours",
#         "value": "120"
#       }
#     ],
#     "customSubDomainName": null,
#     "dateCreated": "2023-01-21T16:48:18.6955304Z",
#     "deletionDate": null,
#     "disableLocalAuth": null,
#     "dynamicThrottlingEnabled": null,
#     "encryption": null,
#     "endpoint": "https://southcentralus.api.cognitive.microsoft.com/",
#     "endpoints": {
#       "OpenAI Language Model Instance API": "https://southcentralus.api.cognitive.microsoft.com/"
#     },
#     "internalId": "91bd9b1c351641668f3308964b70d34e",
#     "isMigrated": false,
#     "migrationToken": null,
#     "networkAcls": null,
#     "privateEndpointConnections": [],
#     "provisioningState": "Succeeded",
#     "publicNetworkAccess": "Enabled",
#     "quotaLimit": null,
#     "restore": null,
#     "restrictOutboundNetworkAccess": null,
#     "scheduledPurgeDate": null,
#     "skuChangeInfo": null,
#     "userOwnedStorage": null
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "sku": {
#     "capacity": null,
#     "family": null,
#     "name": "S0",
#     "size": null,
#     "tier": null
#   },
#   "systemData": {
#     "createdAt": "2023-01-21T16:48:18.475988+00:00",
#     "createdBy": "louisli@microsoft.com",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-01-21T16:48:18.475988+00:00",
#     "lastModifiedBy": "louisli@microsoft.com",
#     "lastModifiedByType": "User"
#   },
#   "tags": null,
#   "type": "Microsoft.CognitiveServices/accounts"
# }

# %%
# !az cognitiveservices account show -n $openai_svc_name -g $openai_rg_name
# Out:
# {
#   "etag": "\"ca0063d3-0000-0500-0000-63cc177d0000\"",
#   "id": "/subscriptions/8480def5-8f7a-4285-99f7-295b61d7b22a/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource",
#   "identity": null,
#   "kind": "OpenAI",
#   "location": "southcentralus",
#   "name": "MyOpenAIResource",
#   "properties": {
#     "allowedFqdnList": null,
#     "apiProperties": null,
#     "callRateLimit": {
#       "count": null,
#       "renewalPeriod": null,
#       "rules": [
#         {
#           "count": 30.0,
#           "dynamicThrottlingEnabled": null,
#           "key": "openai",
#           "matchPatterns": [
#             {
#               "method": "*",
#               "path": "openai/*"
#             }
#           ],
#           "minCount": null,
#           "renewalPeriod": 1.0
#         },
#         {
#           "count": 30.0,
#           "dynamicThrottlingEnabled": null,
#           "key": "default",
#           "matchPatterns": [
#             {
#               "method": "*",
#               "path": "*"
#             }
#           ],
#           "minCount": null,
#           "renewalPeriod": 1.0
#         }
#       ]
#     },
#     "capabilities": [
#       {
#         "name": "VirtualNetworks",
#         "value": null
#       },
#       {
#         "name": "MaxFineTuneCount",
#         "value": "100"
#       },
#       {
#         "name": "MaxRunningFineTuneCount",
#         "value": "1"
#       },
#       {
#         "name": "MaxUserFileCount",
#         "value": "50"
#       },
#       {
#         "name": "MaxTrainingFileSize",
#         "value": "100000000"
#       },
#       {
#         "name": "MaxUserFileImportDurationInHours",
#         "value": "1"
#       },
#       {
#         "name": "MaxFineTuneJobDurationInHours",
#         "value": "120"
#       }
#     ],
#     "customSubDomainName": null,
#     "dateCreated": "2023-01-21T16:48:18.6955304Z",
#     "deletionDate": null,
#     "disableLocalAuth": null,
#     "dynamicThrottlingEnabled": null,
#     "encryption": null,
#     "endpoint": "https://southcentralus.api.cognitive.microsoft.com/",
#     "endpoints": {
#       "OpenAI Language Model Instance API": "https://southcentralus.api.cognitive.microsoft.com/"
#     },
#     "internalId": "91bd9b1c351641668f3308964b70d34e",
#     "isMigrated": false,
#     "migrationToken": null,
#     "networkAcls": null,
#     "privateEndpointConnections": [],
#     "provisioningState": "Succeeded",
#     "publicNetworkAccess": "Enabled",
#     "quotaLimit": null,
#     "restore": null,
#     "restrictOutboundNetworkAccess": null,
#     "scheduledPurgeDate": null,
#     "skuChangeInfo": null,
#     "userOwnedStorage": null
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "sku": {
#     "capacity": null,
#     "family": null,
#     "name": "S0",
#     "size": null,
#     "tier": null
#   },
#   "systemData": {
#     "createdAt": "2023-01-21T16:48:18.475988+00:00",
#     "createdBy": "louisli@microsoft.com",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-01-21T16:48:18.475988+00:00",
#     "lastModifiedBy": "louisli@microsoft.com",
#     "lastModifiedByType": "User"
#   },
#   "tags": null,
#   "type": "Microsoft.CognitiveServices/accounts"
# }

# %%
# !az cognitiveservices account keys list -n $openai_svc_name -g $openai_rg_name
# Out:
# {
#   "key1": "6d9b3176b84c48daafbd88783bb4922c",
#   "key2": "510c52558d52459ba3b25521db1364fb"
# }

# %%
# Deploy a model
search_doc_deployment_name = 'curie-search-doc'
search_doc_model = 'text-search-curie-doc-001'
search_query_deployment_name = 'curie-search-query'
search_query_model = 'text-search-curie-query-001'
text_deployment_name = 'text-davinci-002'
text_model = 'text-davinci-002'

# !az cognitiveservices account deployment create -g $openai_rg_name -n $openai_svc_name --deployment-name $search_doc_deployment_name --model-name $search_doc_model --model-version "1"  --model-format OpenAI --scale-settings-scale-type "Standard"
# Out:
# {
#   "etag": "\"87db97fd-efef-4a94-beaf-f48e5f889d07\"",
#   "id": "/subscriptions/8480def5-8f7a-4285-99f7-295b61d7b22a/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource/deployments/curie-search-doc",
#   "name": "curie-search-doc",
#   "properties": {
#     "callRateLimit": null,
#     "capabilities": {
#       "embeddings": "true",
#       "embeddingsMaxInputs": "1"
#     },
#     "model": {
#       "callRateLimit": null,
#       "format": "OpenAI",
#       "name": "text-search-curie-doc-001",
#       "version": "1"
#     },
#     "provisioningState": "Succeeded",
#     "raiPolicyName": null,
#     "scaleSettings": {
#       "activeCapacity": null,
#       "capacity": null,
#       "scaleType": "Standard"
#     }
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "systemData": {
#     "createdAt": "2023-01-21T17:14:00.456287+00:00",
#     "createdBy": "louisli@microsoft.com",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-01-21T17:14:00.456287+00:00",
#     "lastModifiedBy": "louisli@microsoft.com",
#     "lastModifiedByType": "User"
#   },
#   "type": "Microsoft.CognitiveServices/accounts/deployments"
# }

# %%
# !az cognitiveservices account deployment create -g $openai_rg_name -n $openai_svc_name --deployment-name $search_query_deployment_name --model-name $search_query_model --model-version "1"  --model-format OpenAI --scale-settings-scale-type "Standard"
# !az cognitiveservices account deployment create -g $openai_rg_name -n $openai_svc_name --deployment-name $text_deployment_name --model-name $text_model --model-version "1"  --model-format OpenAI --scale-settings-scale-type "Standard"
# Out:
# {
#   "etag": "\"9476dfbd-f252-4285-9275-1091b93d2244\"",
#   "id": "/subscriptions/8480def5-8f7a-4285-99f7-295b61d7b22a/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource/deployments/curie-search-query",
#   "name": "curie-search-query",
#   "properties": {
#     "callRateLimit": null,
#     "capabilities": {
#       "embeddings": "true",
#       "embeddingsMaxInputs": "1"
#     },
#     "model": {
#       "callRateLimit": null,
#       "format": "OpenAI",
#       "name": "text-search-curie-query-001",
#       "version": "1"
#     },
#     "provisioningState": "Succeeded",
#     "raiPolicyName": null,
#     "scaleSettings": {
#       "activeCapacity": null,
#       "capacity": null,
#       "scaleType": "Standard"
#     }
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "systemData": {
#     "createdAt": "2023-01-21T17:15:49.037589+00:00",
#     "createdBy": "louisli@microsoft.com",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-01-21T17:15:49.037589+00:00",
#     "lastModifiedBy": "louisli@microsoft.com",
#     "lastModifiedByType": "User"
#   },
#   "type": "Microsoft.CognitiveServices/accounts/deployments"
# }
# {
#   "etag": "\"ead126ae-1e67-493b-ad40-827aaf88b4de\"",
#   "id": "/subscriptions/8480def5-8f7a-4285-99f7-295b61d7b22a/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource/deployments/text-davinci-002",
#   "name": "text-davinci-002",
#   "properties": {
#     "callRateLimit": null,
#     "capabilities": {
#       "completion": "true",
#       "search": "true"
#     },
#     "model": {
#       "callRateLimit": null,
#       "format": "OpenAI",
#       "name": "text-davinci-002",
#       "version": "1"
#     },
#     "provisioningState": "Succeeded",
#     "raiPolicyName": null,
#     "scaleSettings": {
#       "activeCapacity": null,
#       "capacity": null,
#       "scaleType": "Standard"
#     }
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "systemData": {
#     "createdAt": "2023-01-21T17:15:04.253482+00:00",
#     "createdBy": "louisli@microsoft.com",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-01-21T17:15:52.917899+00:00",
#     "lastModifiedBy": "louisli@microsoft.com",
#     "lastModifiedByType": "User"
#   },
#   "type": "Microsoft.CognitiveServices/accounts/deployments"
# }
